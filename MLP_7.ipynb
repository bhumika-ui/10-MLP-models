# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
data=pd.read_csv('/content/archive.zip')

# %%
data
# Out:
#       StudentID  Age  Gender  Ethnicity  ...  Music  Volunteering       GPA  GradeClass
# 0          1001   17       1          0  ...      1             0  2.929196         2.0
# 1          1002   18       0          0  ...      0             0  3.042915         1.0
# 2          1003   15       0          2  ...      0             0  0.112602         4.0
# 3          1004   17       1          0  ...      0             0  2.054218         3.0
# 4          1005   17       1          0  ...      0             0  1.288061         4.0
# ...         ...  ...     ...        ...  ...    ...           ...       ...         ...
# 2387       3388   18       1          0  ...      0             0  3.455509         0.0
# 2388       3389   17       0          0  ...      0             0  3.279150         4.0
# 2389       3390   16       1          0  ...      0             1  1.142333         2.0
# 2390       3391   16       1          1  ...      1             0  1.803297         1.0
# 2391       3392   16       1          0  ...      0             1  2.140014         1.0
#
# [2392 rows x 15 columns]

# %%
data.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
x=data[['StudentID','Age','Gender','Absences','Extracurricular','Sports','GPA']]

# %%
y=data[['GradeClass']]

# %%
y.size
# Out:
# 2392

# %%
x
# Out:
#       StudentID  Age  Gender  Absences  Extracurricular  Sports       GPA
# 0          1001   17       1         7                0       0  2.929196
# 1          1002   18       0         0                0       0  3.042915
# 2          1003   15       0        26                0       0  0.112602
# 3          1004   17       1        14                1       0  2.054218
# 4          1005   17       1        17                0       0  1.288061
# ...         ...  ...     ...       ...              ...     ...       ...
# 2387       3388   18       1         2                1       0  3.455509
# 2388       3389   17       0         4                0       1  3.279150
# 2389       3390   16       1        20                0       0  1.142333
# 2390       3391   16       1        17                0       1  1.803297
# 2391       3392   16       1        13                0       0  2.140014
#
# [2392 rows x 7 columns]

# %%
y
# Out:
#       GradeClass
# 0            2.0
# 1            1.0
# 2            4.0
# 3            3.0
# 4            4.0
# ...          ...
# 2387         0.0
# 2388         4.0
# 2389         2.0
# 2390         1.0
# 2391         1.0
#
# [2392 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler , LabelEncoder
le=LabelEncoder()
x
# Out:
#       StudentID  Age  Gender  Absences  Extracurricular  Sports       GPA
# 0          1001   17       1         7                0       0  2.929196
# 1          1002   18       0         0                0       0  3.042915
# 2          1003   15       0        26                0       0  0.112602
# 3          1004   17       1        14                1       0  2.054218
# 4          1005   17       1        17                0       0  1.288061
# ...         ...  ...     ...       ...              ...     ...       ...
# 2387       3388   18       1         2                1       0  3.455509
# 2388       3389   17       0         4                0       1  3.279150
# 2389       3390   16       1        20                0       0  1.142333
# 2390       3391   16       1        17                0       1  1.803297
# 2391       3392   16       1        13                0       0  2.140014
#
# [2392 rows x 7 columns]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.73132686,  0.47291901,  0.97849211, ..., -0.78847633,
#         -0.66013204,  1.11808631],
#        [-1.72987865,  1.36294441, -1.02198065, ..., -0.78847633,
#         -0.66013204,  1.24237446],
#        [-1.72843045, -1.30713178, -1.02198065, ..., -0.78847633,
#         -0.66013204, -1.96027719],
#        ...,
#        [ 1.72843045, -0.41710638,  0.97849211, ..., -0.78847633,
#         -0.66013204, -0.83484487],
#        [ 1.72987865, -0.41710638,  0.97849211, ..., -0.78847633,
#          1.51484845, -0.11245195],
#        [ 1.73132686, -0.41710638,  0.97849211, ..., -0.78847633,
#         -0.66013204,  0.25555918]])

# %%
from keras.utils import to_categorical
y_encoded=le.fit_transform(y)
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y_encoded,test_size=0.2)
x_train.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# (1913, 7)

# %%
model=Sequential()
model.add(Dense(64,input_shape=(x_train.shape[1],),activation='relu'))
model.add(Dense(32,activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 64)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │           2,080 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,592 (10.12 KB)
#  Trainable params: 2,592 (10.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=80)
# Out:
# Epoch 1/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8351 - loss: 0.5328
# Epoch 2/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8396 - loss: 0.5191
# Epoch 3/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8380 - loss: 0.5186
# Epoch 4/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8515 - loss: 0.4967
# Epoch 5/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8368 - loss: 0.5474
# Epoch 6/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8509 - loss: 0.5043
# Epoch 7/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8496 - loss: 0.4944
# Epoch 8/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8668 - loss: 0.4632
# Epoch 9/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8686 - loss: 0.4822
# Epoch 10/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8628 - loss: 0.4762
# Epoch 11/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8623 - loss: 0.4917
# Epoch 12/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8618 - loss: 0.4864
# Epoch 13/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8543 - loss: 0.4753
# Epoch 14/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.4654
# Epoch 15/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8623 - loss: 0.4488
# Epoch 16/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8676 - loss: 0.4386
# Epoch 17/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8740 - loss: 0.4614
# Epoch 18/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8715 - loss: 0.4380
# Epoch 19/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8728 - loss: 0.4377
# Epoch 20/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.4420
# Epoch 21/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8672 - loss: 0.4454
# Epoch 22/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8637 - loss: 0.4406
# Epoch 23/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8853 - loss: 0.4061
# Epoch 24/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8774 - loss: 0.4547
# Epoch 25/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8708 - loss: 0.4116
# Epoch 26/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8850 - loss: 0.4129
# Epoch 27/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8738 - loss: 0.4192
# Epoch 28/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8701 - loss: 0.4613
# Epoch 29/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8828 - loss: 0.4246
# Epoch 30/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8808 - loss: 0.4034
# Epoch 31/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.4435
# Epoch 32/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8859 - loss: 0.4083
# Epoch 33/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8758 - loss: 0.3963
# Epoch 34/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8849 - loss: 0.3954
# Epoch 35/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8837 - loss: 0.4115
# Epoch 36/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8850 - loss: 0.3835
# Epoch 37/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8933 - loss: 0.4023
# Epoch 38/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9027 - loss: 0.3726
# Epoch 39/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8745 - loss: 0.4135
# Epoch 40/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9029 - loss: 0.3676
# Epoch 41/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8886 - loss: 0.3970
# Epoch 42/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8847 - loss: 0.4005
# Epoch 43/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8953 - loss: 0.3785
# Epoch 44/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8871 - loss: 0.3922
# Epoch 45/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.3833
# Epoch 46/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8767 - loss: 0.3875
# Epoch 47/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8764 - loss: 0.4132
# Epoch 48/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8863 - loss: 0.3852
# Epoch 49/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8836 - loss: 0.3842
# Epoch 50/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.3624
# Epoch 51/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9017 - loss: 0.3569
# Epoch 52/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8995 - loss: 0.3926
# Epoch 53/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8931 - loss: 0.3993
# Epoch 54/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8940 - loss: 0.3640
# Epoch 55/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9072 - loss: 0.3388
# Epoch 56/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8866 - loss: 0.3820
# Epoch 57/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8970 - loss: 0.3829
# Epoch 58/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8948 - loss: 0.3634
# Epoch 59/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8896 - loss: 0.3724
# Epoch 60/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.3761
# Epoch 61/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8949 - loss: 0.3597
# Epoch 62/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8969 - loss: 0.3532
# Epoch 63/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8941 - loss: 0.3801
# Epoch 64/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8961 - loss: 0.3650
# Epoch 65/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9054 - loss: 0.3549
# Epoch 66/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9038 - loss: 0.3572
# Epoch 67/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9008 - loss: 0.3557
# Epoch 68/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8942 - loss: 0.3825
# Epoch 69/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8926 - loss: 0.3868
# Epoch 70/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.3748
# Epoch 71/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9134 - loss: 0.3688
# Epoch 72/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9015 - loss: 0.3352
# Epoch 73/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8982 - loss: 0.3593
# Epoch 74/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9014 - loss: 0.3466
# Epoch 75/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8925 - loss: 0.3758
# Epoch 76/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9145 - loss: 0.3235
# Epoch 77/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9130 - loss: 0.3201
# Epoch 78/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.3520
# Epoch 79/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9071 - loss: 0.3245
# Epoch 80/80
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.3382

# %%
model.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
loss,accuracy=model.evaluate(x_test,y_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8549 - loss: 0.3941

# %%
print('Loss',loss)
print('Accuracy',accuracy)
# Out:
# Loss 0.4036560356616974
# Accuracy 0.8622129559516907
