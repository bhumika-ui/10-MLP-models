# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
data=pd.read_csv("/content/online_course_engagement_data.csv")

# %%
data
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618         Health          29.979719                     17
# 1       4326           Arts          27.802640                      1
# 2       5849           Arts          86.820485                     14
# 3       4992        Science          35.038427                     17
# 4       3866    Programming          92.490647                     16
# ...      ...            ...                ...                    ...
# 8995    8757         Health          37.445225                     14
# 8996     894        Science          48.631443                      7
# 8997    6323         Health          38.212512                      3
# 8998    3652         Health          70.048665                     13
# 8999    5595         Health          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType  \
# 0                        3   50.365656       20.860773           1
# 1                        5   62.615970       65.632415           1
# 2                        2   78.458962       63.812007           1
# 3                       10   59.198853       95.433162           0
# 4                        0   98.428285       18.102478           0
# ...                    ...         ...             ...         ...
# 8995                     4   54.469359       32.990704           1
# 8996                     7   59.413257        0.254625           0
# 8997                     3   69.508297       70.188159           1
# 8998                    10   79.655182       72.975225           1
# 8999                     5   56.274546       11.299071           0
#
#       CourseCompletion
# 0                    0
# 1                    0
# 2                    1
# 3                    1
# 4                    0
# ...                ...
# 8995                 0
# 8996                 0
# 8997                 0
# 8998                 1
# 8999                 0
#
# [9000 rows x 9 columns]

# %%
data.columns
# Out:
# Index(['UserID', 'CourseCategory', 'TimeSpentOnCourse',
#        'NumberOfVideosWatched', 'NumberOfQuizzesTaken', 'QuizScores',
#        'CompletionRate', 'DeviceType', 'CourseCompletion'],
#       dtype='object')

# %%
x=data[['UserID', 'CourseCategory', 'TimeSpentOnCourse',
       'NumberOfVideosWatched', 'NumberOfQuizzesTaken', 'QuizScores',
       'CompletionRate', 'DeviceType']]
x
# Out:
#       UserID CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618         Health          29.979719                     17
# 1       4326           Arts          27.802640                      1
# 2       5849           Arts          86.820485                     14
# 3       4992        Science          35.038427                     17
# 4       3866    Programming          92.490647                     16
# ...      ...            ...                ...                    ...
# 8995    8757         Health          37.445225                     14
# 8996     894        Science          48.631443                      7
# 8997    6323         Health          38.212512                      3
# 8998    3652         Health          70.048665                     13
# 8999    5595         Health          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType
# 0                        3   50.365656       20.860773           1
# 1                        5   62.615970       65.632415           1
# 2                        2   78.458962       63.812007           1
# 3                       10   59.198853       95.433162           0
# 4                        0   98.428285       18.102478           0
# ...                    ...         ...             ...         ...
# 8995                     4   54.469359       32.990704           1
# 8996                     7   59.413257        0.254625           0
# 8997                     3   69.508297       70.188159           1
# 8998                    10   79.655182       72.975225           1
# 8999                     5   56.274546       11.299071           0
#
# [9000 rows x 8 columns]

# %%
y=data[['CourseCompletion']]
y
# Out:
#       CourseCompletion
# 0                    0
# 1                    0
# 2                    1
# 3                    1
# 4                    0
# ...                ...
# 8995                 0
# 8996                 0
# 8997                 0
# 8998                 1
# 8999                 0
#
# [9000 rows x 1 columns]

# %%
x.shape
# Out:
# (9000, 8)

# %%
y.shape

# %%
x.size

# %%
y.size

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
x['CourseCategory']=le.fit_transform(x['CourseCategory'])
x
# Out:
# <ipython-input-10-5088188aa8d7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['CourseCategory']=le.fit_transform(x['CourseCategory'])
#       UserID  CourseCategory  TimeSpentOnCourse  NumberOfVideosWatched  \
# 0       5618               2          29.979719                     17
# 1       4326               0          27.802640                      1
# 2       5849               0          86.820485                     14
# 3       4992               4          35.038427                     17
# 4       3866               3          92.490647                     16
# ...      ...             ...                ...                    ...
# 8995    8757               2          37.445225                     14
# 8996     894               4          48.631443                      7
# 8997    6323               2          38.212512                      3
# 8998    3652               2          70.048665                     13
# 8999    5595               2          93.589781                      7
#
#       NumberOfQuizzesTaken  QuizScores  CompletionRate  DeviceType
# 0                        3   50.365656       20.860773           1
# 1                        5   62.615970       65.632415           1
# 2                        2   78.458962       63.812007           1
# 3                       10   59.198853       95.433162           0
# 4                        0   98.428285       18.102478           0
# ...                    ...         ...             ...         ...
# 8995                     4   54.469359       32.990704           1
# 8996                     7   59.413257        0.254625           0
# 8997                     3   69.508297       70.188159           1
# 8998                    10   79.655182       72.975225           1
# 8999                     5   56.274546       11.299071           0
#
# [9000 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler , OneHotEncoder

# %%
scaler=StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 0.43097132, -0.01304652, -0.70845858, ..., -1.69293893,
#         -1.018308  ,  0.99866755],
#        [-0.06658228, -1.43630377, -0.78487371, ..., -0.84089635,
#          0.52824188,  0.99866755],
#        [ 0.5199302 , -1.43630377,  1.2866426 , ...,  0.26102679,
#          0.46535938,  0.99866755],
#        ...,
#        [ 0.70246922, -0.01304652, -0.41948898, ..., -0.36151627,
#          0.68561124,  0.99866755],
#        [-0.32614198, -0.01304652,  0.6979546 , ...,  0.34422714,
#          0.78188507,  0.99866755],
#        [ 0.42211394, -0.01304652,  1.52424375, ..., -1.2819596 ,
#         -1.34859851, -1.00133422]])

# %%
from keras.utils import to_categorical
y_encoded=to_categorical(y)
x_train,x_test,y_train,y_test=train_test_split(x,y_encoded,test_size=0.2,random_state=42)
x_train.shape
#x_test.shape
#y_train.shape
#y_test.shape
# Out:
# (7200, 8)

# %%
model=Sequential()
model.add(Dense(32,input_shape=(x_train.shape[1],),activation='relu'))
model.add(Dense(2,activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 32)                  │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 354 (1.38 KB)
#  Trainable params: 354 (1.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7092 - loss: 0.5648
# Epoch 2/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8129 - loss: 0.4154
# Epoch 3/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8127 - loss: 0.3983
# Epoch 4/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8254 - loss: 0.3763
# Epoch 5/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8374 - loss: 0.3617
# Epoch 6/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8433 - loss: 0.3493
# Epoch 7/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8483 - loss: 0.3457
# Epoch 8/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8488 - loss: 0.3352
# Epoch 9/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8497 - loss: 0.3282
# Epoch 10/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8531 - loss: 0.3297
# Epoch 11/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8581 - loss: 0.3273
# Epoch 12/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8570 - loss: 0.3262
# Epoch 13/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8654 - loss: 0.3131
# Epoch 14/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8684 - loss: 0.3138
# Epoch 15/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8627 - loss: 0.3130
# Epoch 16/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8596 - loss: 0.3232
# Epoch 17/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8734 - loss: 0.3001
# Epoch 18/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8685 - loss: 0.3082
# Epoch 19/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8728 - loss: 0.3069
# Epoch 20/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8791 - loss: 0.2951
# Epoch 21/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8762 - loss: 0.2949
# Epoch 22/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8702 - loss: 0.3041
# Epoch 23/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8742 - loss: 0.3046
# Epoch 24/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8778 - loss: 0.2933
# Epoch 25/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8729 - loss: 0.3002
# Epoch 26/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8771 - loss: 0.2938
# Epoch 27/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8847 - loss: 0.2841
# Epoch 28/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8794 - loss: 0.2947
# Epoch 29/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8813 - loss: 0.2932
# Epoch 30/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8766 - loss: 0.2837
# Epoch 31/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.2957
# Epoch 32/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8788 - loss: 0.2944
# Epoch 33/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8780 - loss: 0.2949
# Epoch 34/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8834 - loss: 0.2812
# Epoch 35/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8811 - loss: 0.2839
# Epoch 36/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8809 - loss: 0.2788
# Epoch 37/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8875 - loss: 0.2812
# Epoch 38/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8825 - loss: 0.2840
# Epoch 39/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8802 - loss: 0.2863
# Epoch 40/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8780 - loss: 0.2875
# Epoch 41/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8778 - loss: 0.2868
# Epoch 42/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8864 - loss: 0.2755
# Epoch 43/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8778 - loss: 0.2883
# Epoch 44/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8861 - loss: 0.2749
# Epoch 45/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8854 - loss: 0.2727
# Epoch 46/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8852 - loss: 0.2804
# Epoch 47/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8857 - loss: 0.2723
# Epoch 48/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8829 - loss: 0.2834
# Epoch 49/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8904 - loss: 0.2642
# Epoch 50/50
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8864 - loss: 0.2706

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
loss,accuracy=model.evaluate(x_test,y_test)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8728 - loss: 0.2885

# %%
print('loss:',loss)
print('accuracy:',accuracy)
# Out:
# loss: 0.3003534972667694
# accuracy: 0.8700000047683716
